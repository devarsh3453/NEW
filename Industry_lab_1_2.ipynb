# %% [markdown]
# <a href="https://colab.research.google.com/github/devarsh3453/NEW/blob/main/Industry_lab_1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creating a list
my_list = [0,2,4,6,8,98]
print(my_list)
# Out:
# [0, 2, 4, 6, 8, 98]

# %%
from array import array

# Creating an array of integer type
my_array = array('i', [1,3,5,7,9])
print(my_array)
# Out:
# array('i', [1, 3, 5, 7, 9])

# %%
# Accessing the first element
print(my_list[0])
print(my_array[0])
# Out:
# 0
# 1

# %%
# Modifying the first element
my_list[0] = 100
my_array[0] = 101

print(my_list)
print(my_array)
# Out:
# [100, 2, 4, 6, 8, 98]
# array('i', [101, 3, 5, 7, 9])

# %%
print(len(my_list) )
print(len(my_array))
# Out:
# 6
# 5
